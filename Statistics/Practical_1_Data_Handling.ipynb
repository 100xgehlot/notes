# %%
import pandas as pd
cars_data = pd.read_csv("..\Datasets\Toyota.csv",index_col=0)
cars_data.head()
# Out:
#       Price   Age     KM FuelType   HP  MetColor  Automatic    CC  Doors  \
# 0     13500  23.0  46986   Diesel   90       1.0          0  2000  three
# 1     13750  23.0  72937   Diesel   90       1.0          0  2000      3
# 2     13950  24.0  41711   Diesel   90       NaN          0  2000      3
# 3     14950  26.0  48000   Diesel   90       0.0          0  2000      3
# 4     13750  30.0  38500   Diesel   90       0.0          0  2000      3
# ...     ...   ...    ...      ...  ...       ...        ...   ...    ...
# 1431   7500   NaN  20544   Petrol   86       1.0          0  1300      3
# 1432  10845  72.0     ??   Petrol   86       0.0          0  1300      3
# 1433   8500   NaN  17016   Petrol   86       0.0          0  1300      3
# 1434   7250  70.0     ??      NaN   86       1.0          0  1300      3
# 1435   6950  76.0      1   Petrol  110       0.0          0  1600      5
#
#       Weight
# 0       1165
# 1       1165
# 2       1165
# 3       1165
# 4       1170
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(cars_data["Age"],cars_data["Price"],c="red")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

x = range(1,6)
y = np.random.randint(1,20,5)
plt.plot(x,y)

plt.xticks(x)
plt.xticks(y)
# Out:
# ([<matplotlib.axis.XTick at 0x11372c17130>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
import matplotlib.pyplot as plt

fig,ax = plt.subplots()
x=[2,4,6,7,7,1,0,3,6,3,6,1,3,6,4]
y=[7,5,3,9,2,0,1,6,2,8,3,7,4,6,7]

ax.plot(x,y)

# %%
import pandas as pd
df = pd.DataFrame({
    "name":["john","mary","peter","jeff","bill","lisa","jose"],
    "age":[23,78,22,19,45,33,20],
    "gender":["M","F","M","M","M","F","M"],
    "state":["california","dc","california","dc","california","texas","New York"],
    "nums_childern":[2,0,0,3,2,1,4],
    "nums_pets":[5,1,0,5,2,2,3]
})
#from pandas to plot multiple plot on same figure
#gca stands for get current axis

ax = plt.gca()

df.plot(kind="line",x="name",y="nums_childern",ax=ax)
df.plot(kind="line",x="name",y="nums_pets",ax=ax)
# Out:
# <AxesSubplot:xlabel='name'>

# %%
import pandas as pd
iris  = pd.read_csv("..\Datasets\Iris.csv",index_col=0)
df = pd.DataFrame({
   "SepalLengthCm": iris["SepalLengthCm"],
    "SepalWidthCm": iris["SepalWidthCm"],
    "PetalLengthCm": iris["PetalLengthCm"],
    "PetalWidthCm": iris["PetalWidthCm"]
})
#from pandas to plot multiple plot on same figure
#gca stands for get current axis

ax = plt.gca()
df.plot(kind="line", y="SepalLengthCm", ax=ax)
df.plot(kind="line", y="SepalWidthCm", ax=ax)
df.plot(kind="line", y="PetalLengthCm", ax=ax)
df.plot(kind="line", y="PetalWidthCm", ax=ax)

data
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9           3.0            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# get columns to plot 
columns=iris.columns.drop(['Species'])
# create x data 
x_data=range(0, iris.shape[0]) 
# crate figure and axis 
fig, ax=plt.subplots() 


for column in columns: 
    ax.plot(x_data, iris[column],label=column)
    
# plot each columns for column in columns: 
# set title and legend 
ax.set_title('Iris Dataset') 
ax.legend()
