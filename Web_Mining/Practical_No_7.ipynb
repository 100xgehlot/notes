# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import csv

def focused_crawl(url, keyword, depth=1, visited=None, csv_writer=None, parent_url=None):
    if visited is None:
        visited = set()

    if depth == 0 or url in visited:
        return

    print(f"Crawling: {url} (Found on: {parent_url})")
    visited.add(url)
    try:
        response = requests.get(url, timeout=5)
        if response.status_code != 200:
            return

        soup = BeautifulSoup(response.text, 'html.parser')

        if keyword.lower() in soup.get_text().lower():
            print(f"Keyword '{keyword}' found on {url}")
            if csv_writer:
                    csv_writer.writerow([url, parent_url])

        links = [urljoin(url, a['href']) for a in soup.find_all('a', href=True)]

        for link in links:
            if link.startswith("http") or link.startswith("https"):
                focused_crawl(link, keyword, depth - 1, visited, csv_writer, url)

    except requests.RequestException as e:
        print(f"Error: {e}")

# %%
# Start crawling from a given URL with a keyword filter
# start_url = "https://example.com"
start_url = "https://www.scrapingbee.com/blog/crawling-python/"
search_keyword = "scraping"

with open("focused_crawled_links.csv", "w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["URL", "Found On"])
    focused_crawl(start_url, search_keyword, depth=2, csv_writer=writer, parent_url="Root")
# Out:
# Crawling: https://www.scrapingbee.com/blog/crawling-python/ (Found on: Root)
# Keyword 'scraping' found on https://www.scrapingbee.com/blog/crawling-python/
# Crawling: https://app.scrapingbee.com/account/register (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://app.scrapingbee.com/account/register
# Crawling: https://www.scrapingbee.com/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/
# Crawling: https://app.scrapingbee.com/account/login (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://app.scrapingbee.com/account/login
# Crawling: https://www.scrapingbee.com/pricing/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/pricing/
# Crawling: https://www.scrapingbee.com/faq/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/faq/
# Crawling: https://www.scrapingbee.com/blog/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/blog/
# Crawling: https://www.scrapingbee.com/features/markdown-scraper/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/features/markdown-scraper/
# Crawling: https://www.scrapingbee.com/features/ai-web-scraping-api/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/features/ai-web-scraping-api/
# Crawling: https://www.scrapingbee.com/features/data-extraction/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/features/data-extraction/
# Crawling: https://www.scrapingbee.com/features/screenshot/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/features/screenshot/
# Crawling: https://www.scrapingbee.com/features/javascript-scenario/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/features/javascript-scenario/
# Crawling: https://www.scrapingbee.com/features/make/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/features/make/
# Crawling: https://www.scrapingbee.com/features/n8n/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/features/n8n/
# Crawling: https://mcp.scrapingbee.com/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://mcp.scrapingbee.com/
# Crawling: https://www.scrapingbee.com/features/google/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/features/google/
# Crawling: https://www.scrapingbee.com/features/amazon/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/features/amazon/
# Crawling: https://www.scrapingbee.com/features/youtube/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/features/youtube/
# Crawling: https://www.scrapingbee.com/features/walmart/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/features/walmart/
# Crawling: https://www.scrapingbee.com/features/chatgpt/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/features/chatgpt/
# Crawling: https://www.scrapingbee.com/tutorials (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/tutorials
# Crawling: https://www.scrapingbee.com/documentation/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/documentation/
# Crawling: https://help.scrapingbee.com/en/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://help.scrapingbee.com/en/
# Crawling: https://www.scrapingbee.com/blog/scraping-vs-crawling/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/blog/scraping-vs-crawling/
# Crawling: https://www.scrapingbee.com/blog/what-is-web-scraping-and-how-to-scrape-any-website-tutorial/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/blog/what-is-web-scraping-and-how-to-scrape-any-website-tutorial/
# Crawling: https://github.com/astral-sh/uv (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Crawling: https://www.scrapingbee.com/curl-converter/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/curl-converter/
# Crawling: https://www.scrapingbee.com/blog/how-to-find-all-urls-on-a-domains-website-multiple-methods/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/blog/how-to-find-all-urls-on-a-domains-website-multiple-methods/
# Crawling: https://www.scrapingbee.com/blog/how-to-bypass-recaptcha-and-hcaptcha-when-web-scraping/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/blog/how-to-bypass-recaptcha-and-hcaptcha-when-web-scraping/
# Crawling: https://www.scrapy.org/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapy.org/
# Crawling: https://www.scrapingbee.com/blog/scrapy-playwright-tutorial/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/blog/scrapy-playwright-tutorial/
# Crawling: https://docs.scrapy.org/en/latest/topics/autothrottle.html (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://docs.scrapy.org/en/latest/topics/autothrottle.html
# Crawling: https://scrapyd.readthedocs.io/en/latest/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Crawling: https://github.com/rmax/scrapy-redis (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://github.com/rmax/scrapy-redis
# Crawling: https://michaelnielsen.org/ddi/how-to-crawl-a-quarter-billion-webpages-in-40-hours/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://michaelnielsen.org/ddi/how-to-crawl-a-quarter-billion-webpages-in-40-hours/
# Crawling: https://twitter.com/ari_bajo (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Crawling: https://www.scrapingbee.com/blog/web-scraping-with-scrapy/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/blog/web-scraping-with-scrapy/
# Crawling: https://www.scrapingbee.com/blog/python-curl/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/blog/python-curl/
# Crawling: https://www.scrapingbee.com/blog/introduction-to-web-scraping-with-java/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/blog/introduction-to-web-scraping-with-java/
# Crawling: https://twitter.com/ScrapingBee (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Crawling: https://www.linkedin.com/company/scrapingbee (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Crawling: https://www.scrapingbee.com/#about-us (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/#about-us
# Crawling: https://www.scrapingbee.com/journey-to-one-million-arr/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/journey-to-one-million-arr/
# Crawling: https://www.scrapingbee.com/rebranding/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/rebranding/
# Crawling: https://www.scrapingbee.com/affiliates/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/affiliates/
# Crawling: https://www.scrapingbee.com/terms-and-conditions/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/terms-and-conditions/
# Crawling: https://www.scrapingbee.com/privacy-policy/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/privacy-policy/
# Crawling: https://www.scrapingbee.com/gdpr/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/gdpr/
# Crawling: https://www.scrapingbee.com/data-processing-agreement/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/data-processing-agreement/
# Crawling: https://www.scrapingbee.com/cookie-policy/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/cookie-policy/
# Crawling: https://www.scrapingbee.com/acceptable-use-policy/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/acceptable-use-policy/
# Crawling: https://www.scrapingbee.com/legal-notices/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/legal-notices/
# Crawling: https://www.scrapingbee.com/#features (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/#features
# Crawling: https://status.scrapingbee.com (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Crawling: https://www.scrapingbee.com/crawlera-alternative/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/crawlera-alternative/
# Crawling: https://www.scrapingbee.com/netnut-alternative/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/netnut-alternative/
# Crawling: https://www.scrapingbee.com/scraperapi-alternative/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/scraperapi-alternative/
# Crawling: https://www.scrapingbee.com/scrapingbee-alternative/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/scrapingbee-alternative/
# Crawling: https://www.scrapingbee.com/scrapers/google-shopping-api/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/scrapers/google-shopping-api/
# Crawling: https://www.scrapingbee.com/scrapers/homedepot-scraper-api/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/scrapers/homedepot-scraper-api/
# Crawling: https://www.scrapingbee.com/scrapers/costco-scraper-api/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/scrapers/costco-scraper-api/
# Crawling: https://www.scrapingbee.com/scrapers/expedia-scraper-api/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/scrapers/expedia-scraper-api/
# Crawling: https://www.scrapingbee.com/scrapers/google-jobs-scraper-api/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/scrapers/google-jobs-scraper-api/
# Crawling: https://www.scrapingbee.com/scrapers/google-news-scraper-api/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/scrapers/google-news-scraper-api/
# Crawling: https://www.scrapingbee.com/scrapers/google-play-scraper-api/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/scrapers/google-play-scraper-api/
# Crawling: https://www.scrapingbee.com/scrapers/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/scrapers/
# Crawling: https://www.scrapingbee.com/blog/no-code-web-scraping/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/blog/no-code-web-scraping/
# Crawling: https://www.scrapingbee.com/blog/no-code-competitor-monitoring/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/blog/no-code-competitor-monitoring/
# Crawling: https://www.scrapingbee.com/webscraping-questions/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/webscraping-questions/
# Crawling: https://www.scrapingbee.com/blog/web-scraping-without-getting-blocked/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/blog/web-scraping-without-getting-blocked/
# Crawling: https://www.scrapingbee.com/blog/web-scraping-tools/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/blog/web-scraping-tools/
# Crawling: https://www.scrapingbee.com/blog/best-free-proxy-list-web-scraping/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/blog/best-free-proxy-list-web-scraping/
# Crawling: https://www.scrapingbee.com/blog/best-mobile-4g-proxy-provider-webscraping/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/blog/best-mobile-4g-proxy-provider-webscraping/
# Crawling: https://www.scrapingbee.com/blog/rotating-proxies/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/blog/rotating-proxies/
# Crawling: https://www.scrapingbee.com/blog/web-scraping-101-with-python/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/blog/web-scraping-101-with-python/
# Crawling: https://www.scrapingbee.com/blog/web-scraping-php/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/blog/web-scraping-php/
# Crawling: https://www.scrapingbee.com/blog/web-scraping-ruby/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/blog/web-scraping-ruby/
# Crawling: https://www.scrapingbee.com/blog/web-scraping-javascript/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/blog/web-scraping-javascript/
# Crawling: https://www.scrapingbee.com/blog/web-scraping-r/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/blog/web-scraping-r/
# Crawling: https://www.scrapingbee.com/blog/web-scraping-csharp/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/blog/web-scraping-csharp/
# Crawling: https://www.scrapingbee.com/blog/web-scraping-c++/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/blog/web-scraping-c++/
# Crawling: https://www.scrapingbee.com/blog/web-scraping-elixir/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/blog/web-scraping-elixir/
# Crawling: https://www.scrapingbee.com/blog/web-scraping-perl/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/blog/web-scraping-perl/
# Crawling: https://www.scrapingbee.com/blog/web-scraping-rust/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/blog/web-scraping-rust/
# Crawling: https://www.scrapingbee.com/blog/web-scraping-go/ (Found on: https://www.scrapingbee.com/blog/crawling-python/)
# Keyword 'scraping' found on https://www.scrapingbee.com/blog/web-scraping-go/
