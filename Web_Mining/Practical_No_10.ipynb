# %%
pip install textblob
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from textblob import TextBlob
from nltk.sentiment import SentimentIntensityAnalyzer 
import nltk

nltk.download("vader_lexicon")
nltk.download("vader_lexicon")
nltk.download("vader_lexicon")
nltk.download("vader_lexicon")

sample_texts = [
    "I absolutely love this product! It's fantastic and works like a charm.",
    "This is the worst experience I've ever had. So disappointing!",
    "The service was okay, nothing special but not terrible either.",
    "I am feeling really sad and lonely today.",
    "Wow! This is amazing, I couldn't be happier!",
    "Meh, it's just an average product. Nothing too exciting."
]
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
def analyze_sentiment_textblob(text):
    """Analyze sentiment using TextBlob."""
    blob = TextBlob(text)
    sentiment_score = blob.sentiment.polarity   # Range: [-1,1] (Negative to Positive)

    if sentiment_score > 0:
        sentiment = "Positive"
    elif sentiment_score < 0:
        sentiment = "Negative"
    else:
        sentiment = "Neutral"

    return sentiment, sentiment_score


def analyze_sentiment_vader(text):
    """Analyze sentiment using VADER (best for short, social media-like text)."""
    sia = SentimentIntensityAnalyzer()
    sentiment_score = sia.polarity_scores(text)["compound"]   # Compound score

    if sentiment_score > 0:
        sentiment = "Positive"
    elif sentiment_score < 0:
        sentiment = "Negative"
    else:
        sentiment = "Neutral"

    return sentiment, sentiment_score

# %%
# Run sentiment analysis on sample texts
for text in sample_texts:
    textblob_sentiment, textblob_score = analyze_sentiment_textblob(text)
    vader_sentiment, vader_score = analyze_sentiment_vader(text)

    print(f"Text: {text}")
    print(f"  TextBlob Sentiment: {textblob_sentiment} (Score: {textblob_score})")
    print(f"  VADER Sentiment: {vader_sentiment} (Score: {vader_score})")
    print("-" * 80)
# Out:
# Text: I absolutely love this product! It's fantastic and works like a charm.
#   TextBlob Sentiment: Positive (Score: 0.5125)
#   VADER Sentiment: Positive (Score: 0.9272)
# --------------------------------------------------------------------------------
# Text: This is the worst experience I've ever had. So disappointing!
#   TextBlob Sentiment: Negative (Score: -0.875)
#   VADER Sentiment: Negative (Score: -0.8353)
# --------------------------------------------------------------------------------
# Text: The service was okay, nothing special but not terrible either.
#   TextBlob Sentiment: Positive (Score: 0.4523809523809524)
#   VADER Sentiment: Positive (Score: 0.4857)
# --------------------------------------------------------------------------------
# Text: I am feeling really sad and lonely today.
#   TextBlob Sentiment: Negative (Score: -0.3)
#   VADER Sentiment: Negative (Score: -0.6865)
# --------------------------------------------------------------------------------
# ...

# %%
import pandas as pd
from textblob import TextBlob

# Load the dataset
file_path = "tripadvisor_hotel_reviews.csv"
df = pd.read_csv(file_path)

# Function to analyze sentiment
def get_sentiment(review):
    analysis = TextBlob(review)
    return "Positive" if analysis.sentiment.polarity > 0 else "Negative" if analysis.sentiment.polarity < 0 else "Neutral"

# Apply sentiment analysis
df["Sentiment"] = df["Review"].astype(str).apply(get_sentiment)

df[["Review", "Sentiment"]].head()
# Out:
#                                               Review Sentiment
# 0  nice hotel expensive parking got good deal sta...  Positive
# 1  ok nothing special charge diamond member hilto...  Positive
# 2  nice rooms not a* experience hotel monaco seat...  Positive
# 3  unique, great stay, wonderful time! hotel mona...  Positive
# 4  great stay great stay wet, even seahawk game a...  Positive

# %%
# Save the results
df.to_csv("tripadvisor_hotel_reviews_with_sentiment.csv", index=False)
print("Sentiment analysis completed and saved.")
# Out:
# Sentiment analysis completed and saved.
